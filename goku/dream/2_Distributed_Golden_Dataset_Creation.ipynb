# %% [markdown]
# ## Distributed Golden Dataset Creation

# %% [markdown]
# ### Environment Setup

# %%
import os
import ray

# os.environ['OPENAI_API_KEY'] = 'sk_...'
os.environ['RAY_ADDRESS'] = 'ray://localhost:10001'

runtime_env = {
    'pip': [
        'llama-index==0.10.27',
        'boto3==1.34.79',
        'botocore==1.34.79',
        'ipython==8.18.1',
        'pandas==2.2.1',
        'ragas==0.1.7',
        'pypdf2==3.0.1',
        'boto3==1.34.79',
        'langchain==0.1.14',
        'unstructured==0.13.2'
        
    ],
    "env_vars": {
        'AWS_ACCESS_KEY_ID': os.environ['AWS_ACCESS_KEY_ID'],
        'AWS_SECRET_ACCESS_KEY': os.environ['AWS_SECRET_ACCESS_KEY'],
        'HUGGINGFACE_API_TOKEN': os.environ['HUGGINGFACE_API_TOKEN'],
        'OPENAI_API_KEY': os.environ['OPENAI_API_KEY'],
    }

}

ray.init(runtime_env=runtime_env, include_dashboard=True, log_to_driver=False)
# Out:
# 2024-04-10 15:30:35,548	INFO worker.py:1432 -- Using address ray://localhost:10001 set in the environment variable RAY_ADDRESS
# 2024-04-10 15:30:35,578	INFO client_builder.py:244 -- Passing the following kwargs to ray.init() on the server: include_dashboard, log_to_driver
# SIGTERM handler is not set because current thread is not the main thread.
# ClientContext(dashboard_url='10.10.255.231:8265', python_version='3.9.18', ray_version='2.10.0', ray_commit='09abba26b5bf2707639bb637c208d062a47b46f6', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7f712d152160>, protocol_version=None)
# Log channel is reconnecting. Logs produced while the connection was down can be found on the head node of the cluster in `ray_client_server_[port].out`
# 2024-04-10 15:40:19,674	WARNING dataclient.py:403 -- Encountered connection issues in the data channel. Attempting to reconnect.

# %% [markdown]
# ### Distributed Testset Generation (Ragas + Ray)

# %%
BUCKET_NAME = 'unstructured-data'

# %%
import boto3
import os

s3 = boto3.client(
        's3',
        endpoint_url='http://localhost:9000',
        aws_access_key_id=os.environ['AWS_ACCESS_KEY_ID'],
        aws_secret_access_key=os.environ['AWS_SECRET_ACCESS_KEY']
    )

def list_files_in_bucket(bucket_name):
    file_paths = []
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name)

    for page in page_iterator:
        if "Contents" in page:
            for obj in page['Contents']:
                if obj['Key'].lower().endswith('.pdf'):  # Check if the file is a PDF
                    file_paths.append(obj['Key'])

    return file_paths

# %%
@ray.remote
def create_golden_dataset(bucket_name, file_names):
    import os
    import boto3
    import fitz  # PyMuPDF
    import shutil
    import time
    import random
    from llama_index.core import SimpleDirectoryReader
    from ragas.testset.generator import TestsetGenerator
    from langchain_openai import ChatOpenAI, OpenAIEmbeddings

    DIRECTORY_NAME = os.path.join(os.getcwd(), 'data')
    s3_client = boto3.client(
        's3',
        aws_access_key_id=os.environ['AWS_ACCESS_KEY_ID'],
        aws_secret_access_key=os.environ['AWS_SECRET_ACCESS_KEY'],
        endpoint_url='http://minio.minio.svc:9000'
    )
    
    if not os.path.exists(DIRECTORY_NAME):
        os.makedirs(DIRECTORY_NAME)
    
    for file_name in file_names:
        LOCAL_FILE_PATH = os.path.join(DIRECTORY_NAME, file_name)
        
        # Fetch the PDF file from S3
        pdf_file = s3_client.get_object(Bucket=bucket_name, Key=file_name)
        pdf_content = pdf_file['Body'].read()
        
        with open(LOCAL_FILE_PATH, 'wb') as f:
            f.write(pdf_content)

    reader = SimpleDirectoryReader(input_dir=DIRECTORY_NAME)
    documents = reader.load_data()
    
    # Generator with openai models
    generator_llm = ChatOpenAI(model="gpt-3.5-turbo")
    critic_llm = ChatOpenAI(model="gpt-3.5-turbo")
    embeddings = OpenAIEmbeddings()
    
    generator = TestsetGenerator.from_langchain(
        generator_llm,
        critic_llm,
        embeddings
    )
    
    # Generate testset
    try:
        # To get past rate limits
        time.sleep(random.uniform(30, 60))
        testset = generator.generate_with_llamaindex_docs(documents, test_size=3)
    except:
        testset = None
        print("Uh oh!")
    
    shutil.rmtree(DIRECTORY_NAME)
    print(f"Directory {DIRECTORY_NAME} and its contents have been deleted.")
        
    return testset

# %%
pdfs_on_s3 = list_files_in_bucket(BUCKET_NAME)
futures = []
# Process up to 3 PDFs at a time
for i in range(0, len(pdfs_on_s3), 3):
    batch = pdfs_on_s3[i:i+3]
    future = create_golden_dataset.remote(BUCKET_NAME, batch)
    futures.append(future)

combined_golden_testsets = ray.get(futures)

# %%
import pandas as pd
combined_golden_df = pd.DataFrame()
for testset in combined_golden_testsets:
    combined_golden_df = pd.concat([combined_golden_df, testset.to_pandas()], ignore_index=True)

combined_golden_df
# Out:
#                                              question  \
# 0   What method was used to determine the antitoxi...
# 1   How were liveweight changes calculated and mon...
# 2   What changes occurred in the cria's respirator...
# 3   What are the mean monthly temperatures in June...
# 4   What factors contributed to the variation in v...
# 5   How was the rupture of the gastrocnemius muscl...
# 6   How did cholesterol levels in female alpacas c...
# 7   What are some potential treatment options for ...
# 8   What is the publication date of the article on...
# 9   What pH range indicates respiratory acidosis i...
# 10  What components are in vet patient records and...
# 11  What was the purpose of obtaining lateral and ...
# 12  How does shearing impact the thermoregulation ...
# 13  How does water absorption in sheep wool during...
# 14  What staining method was used for cytologic an...
# 15  How does capture and translocation impact stre...
# 16  How was plasma cortisol concentration measured...
# 17  How can alpaca fleece production be optimized ...
# 18  How do capture and translocation impact stress...
#
#                                              contexts  \
# 0   [Bentancor et al - perfringens epsilon -toxin ...
# 1   [25 \n20 \n1s e \ni \nIi \n'0 j \n5 \n0 \nFig....
# 2   [ the morning but decreased to 87% by mid-afte...
# 3   [e hasta alcanzar valores de 75 g dim-1 a 10s ...
# 4   [TABLE I.  VITAMIN E CONCENTRATIONS (MG/ KG) O...
# 5   [Conservativemanagementofaruptured\ngastrocnem...
# 6   [ \nconcentrations were different within the m...
# 7   [treatment did not appear to result in direct ...
# 8   [oup.com/af/article/12/4/78/6663962 by guest o...
# 9   [rit (24%). There\nwere no other signs indicat...
# 10  [ation. Information collected from\nthe medica...
# 11  [148   AJVR, Vol 73, No. 1, January 2012were i...
# 12  [ﬂeece the temperature closely followed the ai...
# 13  [ﬂeece the temperature closely followed the ai...
# 14  [148   AJVR, Vol 73, No. 1, January 2012were i...
# 15  [\nVeterinary Medicine (Series A — Physiology ...
# 16  [Impact of wool harvesting in vicunas \n \n \n...
# 17  [Table 5. Staple growth rates (* SE) for femal...
# 18  [\nVeterinary Medicine (Series A — Physiology ...
#
#                                          ground_truth evolution_type  \
# 0   Indirect ELISA was used to determine if indire...         simple
# 1   Liveweight changes were calculated monthly usi...         simple
# 2   The cria's respiratory condition deteriorated ...      reasoning
# 3   June is the coldest month with a mean monthly ...  multi_context
# 4   The variation in vitamin E concentrations in t...         simple
# 5   The rupture of the gastrocnemius muscle in a m...         simple
# 6   Cholesterol concentrations were found to be di...  multi_context
# 7   Surgical plication of the diaphragm is a poten...         simple
# 8                                                 nan         simple
# 9   Respiratory acidosis in alpacas is indicated b...      reasoning
# 10  The components in vet patient records include ...  multi_context
# 11  The purpose of obtaining lateral and dorsovent...         simple
# 12  Shearing has a beneficial effect on thermoregu...         simple
# 13  During rain, water absorption in sheep wool re...      reasoning
# 14  The slides were stained with modified Wright s...  multi_context
# 15  Plasma cortisol is used as an indicator of str...         simple
# 16  Plasma cortisol concentration was measured usi...         simple
# 17  More research is needed to maximize alpaca fle...      reasoning
# 18  Capture and translocation in wildlife species ...  multi_context
#
#                                              metadata  episode_done
# 0   [{'page_label': '2', 'file_name': 'Antibody re...          True
# 1   [{'page_label': '2', 'file_name': 'Alpaca live...          True
# 2   [{'page_label': '785', 'file_name': 'Acute res...          True
# 3   [{'page_label': '1', 'file_name': 'Alpaca live...          True
# 4   [{'page_label': '3', 'file_name': 'Evaluation ...          True
# 5   [{'page_label': '1', 'file_name': 'Conservativ...          True
# 6   [{'page_label': '2', 'file_name': 'Evaluation ...          True
# 7   [{'page_label': '385', 'file_name': 'Neurologi...          True
# 8   [{'page_label': '80', 'file_name': 'Influence ...          True
# 9   [{'page_label': '381', 'file_name': 'Neurologi...          True
# 10  [{'page_label': '380', 'file_name': 'Neurologi...          True
# 11  [{'page_label': '148', 'file_name': 'Respirato...          True
# 12  [{'page_label': '1456', 'file_name': 'Relation...          True
# 13  [{'page_label': '1456', 'file_name': 'Relation...          True
# 14  [{'page_label': '148', 'file_name': 'Respirato...          True
# 15  [{'page_label': '15', 'file_name': 'The physio...          True
# 16  [{'page_label': '6', 'file_name': 'The physiol...          True
# 17  [{'page_label': '5', 'file_name': 'Alpaca live...          True
# 18  [{'page_label': '15', 'file_name': 'The physio...          True

# %%
import re
pattern = r"[^a-zA-Z0-9.,? ]"

# Define a function to replace special characters in a string
def remove_special_chars(s):
    return re.sub(pattern, '', str(s))

# Apply the function to each cell in the DataFrame
combined_golden_df = combined_golden_df.map(remove_special_chars)
combined_golden_df
# Out:
#                                              question  \
# 0   What method was used to determine the antitoxi...
# 1   How were liveweight changes calculated and mon...
# 2   What changes occurred in the crias respiratory...
# 3   What are the mean monthly temperatures in June...
# 4   What factors contributed to the variation in v...
# 5   How was the rupture of the gastrocnemius muscl...
# 6   How did cholesterol levels in female alpacas c...
# 7   What are some potential treatment options for ...
# 8   What is the publication date of the article on...
# 9   What pH range indicates respiratory acidosis i...
# 10  What components are in vet patient records and...
# 11  What was the purpose of obtaining lateral and ...
# 12  How does shearing impact the thermoregulation ...
# 13  How does water absorption in sheep wool during...
# 14  What staining method was used for cytologic an...
# 15  How does capture and translocation impact stre...
# 16  How was plasma cortisol concentration measured...
# 17  How can alpaca fleece production be optimized ...
# 18  How do capture and translocation impact stress...
#
#                                              contexts  \
# 0   Bentancor et al  perfringens epsilon toxin in ...
# 1   25 n20 n1s e ni nIi n0 j n5 n0 nFig. 1. Averag...
# 2    the morning but decreased to 87 by midafterno...
# 3   e hasta alcanzar valores de 75 g dim1 a 10s 8....
# 4   TABLE I.  VITAMIN E CONCENTRATIONS MG KG ON A ...
# 5   Conservativemanagementofarupturedngastrocnemiu...
# 6    nconcentrations were different within the mal...
# 7   treatment did not appear to result in direct i...
# 8   oup.comafarticle124786663962 by guest on 09 Oc...
# 9   rit 24. Therenwere no other signs indicative o...
# 10  ation. Information collected fromnthe medical ...
# 11  148   AJVR, Vol 73, No. 1, January 2012were in...
# 12  eece the temperature closely followed the air ...
# 13  eece the temperature closely followed the air ...
# 14  148   AJVR, Vol 73, No. 1, January 2012were in...
# 15  nVeterinary Medicine Series A  Physiology , Pa...
# 16  Impact of wool harvesting in vicunas n n n nAn...
# 17  Table 5. Staple growth rates  SE for female an...
# 18  nVeterinary Medicine Series A  Physiology , Pa...
#
#                                          ground_truth evolution_type  \
# 0   Indirect ELISA was used to determine if indire...         simple
# 1   Liveweight changes were calculated monthly usi...         simple
# 2   The crias respiratory condition deteriorated f...      reasoning
# 3   June is the coldest month with a mean monthly ...   multicontext
# 4   The variation in vitamin E concentrations in t...         simple
# 5   The rupture of the gastrocnemius muscle in a m...         simple
# 6   Cholesterol concentrations were found to be di...   multicontext
# 7   Surgical plication of the diaphragm is a poten...         simple
# 8                                                 nan         simple
# 9   Respiratory acidosis in alpacas is indicated b...      reasoning
# 10  The components in vet patient records include ...   multicontext
# 11  The purpose of obtaining lateral and dorsovent...         simple
# 12  Shearing has a beneficial effect on thermoregu...         simple
# 13  During rain, water absorption in sheep wool re...      reasoning
# 14  The slides were stained with modified Wright s...   multicontext
# 15  Plasma cortisol is used as an indicator of str...         simple
# 16  Plasma cortisol concentration was measured usi...         simple
# 17  More research is needed to maximize alpaca fle...      reasoning
# 18  Capture and translocation in wildlife species ...   multicontext
#
#                                              metadata episode_done
# 0   pagelabel 2, filename Antibody response to the...         True
# 1   pagelabel 2, filename Alpaca liveweight variat...         True
# 2   pagelabel 785, filename Acute respiratory dist...         True
# 3   pagelabel 1, filename Alpaca liveweight variat...         True
# 4   pagelabel 3, filename Evaluation of cholestero...         True
# 5   pagelabel 1, filename Conservative management ...         True
# 6   pagelabel 2, filename Evaluation of cholestero...         True
# 7   pagelabel 385, filename Neurological Causes of...         True
# 8   pagelabel 80, filename Influence of effects on...         True
# 9   pagelabel 381, filename Neurological Causes of...         True
# 10  pagelabel 380, filename Neurological Causes of...         True
# 11  pagelabel 148, filename Respiratory mechanics ...         True
# 12  pagelabel 1456, filename Relationships between...         True
# 13  pagelabel 1456, filename Relationships between...         True
# 14  pagelabel 148, filename Respiratory mechanics ...         True
# 15  pagelabel 15, filename The physiological impac...         True
# 16  pagelabel 6, filename The physiological impact...         True
# 17  pagelabel 5, filename Alpaca liveweight variat...         True
# 18  pagelabel 15, filename The physiological impac...         True

# %% [markdown]
# ### Save golden dataset to S3

# %%
import io
csv_buffer = io.StringIO()
combined_golden_df.to_csv(csv_buffer, index=False)

s3.put_object(Bucket=BUCKET_NAME, Body=csv_buffer.getvalue(), Key='golden_dataset.csv')
# Out:
# {'ResponseMetadata': {'RequestId': '17C4F5777F822675',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"083f923f435ca42369d80875a11b7f6a"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '17C4F5777F822675',
#    'x-content-type-options': 'nosniff',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Wed, 10 Apr 2024 15:40:51 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"083f923f435ca42369d80875a11b7f6a"'}

# %% [markdown]
# ![](assets/golden_dataset.png)
